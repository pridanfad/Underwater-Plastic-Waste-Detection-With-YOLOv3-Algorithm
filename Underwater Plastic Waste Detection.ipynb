# %%
# For image detection

import cv2
import numpy as np
import matplotlib.pyplot as plt

net = cv2.dnn.readNet('path_to_yolov3custom_final.weights','path_to_yolov3custom.cfg')
classes = []
with open("path_to_classes.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]

layer_names = net.getLayerNames()
output_layers = [layer_names[i - 1] for i in net.getUnconnectedOutLayers()]

img = cv2.imread("path_to_your_image.jpg")
img = cv2.resize(img, (500, 500))
height, width, channels = img.shape
blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)

net.setInput(blob)
outs = net.forward(output_layers)

class_ids = []
confidences = []
boxes = []
for out in outs:
    for detection in out:
        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]
        if confidence > 0.5:
            center_x = int(detection[0] * width)
            center_y = int(detection[1] * height)
            w = int(detection[2] * width)
            h = int(detection[3] * height)
            x = center_x - w / 2
            y = center_y - h / 2
            boxes.append([x, y, w, h])
            confidences.append(float(confidence))
            class_ids.append(class_id)

indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)

font = cv2.FONT_HERSHEY_PLAIN
colors = np.random.uniform(0, 255, size=(len(classes), 3))

for i in range(len(boxes)):
    if i in indexes:
        x, y, w, h = boxes[i]
        label = str(classes[class_ids[i]])
        confidence = confidences[i]
        color = colors[class_ids[i]]
        cv2.rectangle(img, (int(x), int(y)), (int(x + w), int(y + h)), color, 2)
        text = f"{label}: {confidence:.2f}"
        cv2.putText(img, text, (int(x), int(y) - 5), font, 1, color, 2)

cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#For video detection

import cv2
import numpy as np

net = cv2.dnn.readNet('path_to_yolov3custom_final.weights', 'path_to_yolov3custom.cfg')
classes = []
with open("path_to_classes.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]

layer_names = net.getLayerNames()
output_layers = [layer_names[i - 1] for i in net.getUnconnectedOutLayers()]

video_path = 'path_to_your_video.mp4'  # Replace with the path to your video file
cap = cv2.VideoCapture(video_path)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    height, width, channels = frame.shape
    blob = cv2.dnn.blobFromImage(frame, 0.00392, (416, 416), (0, 0, 0), True, crop=False)

    net.setInput(blob)
    outs = net.forward(output_layers)

    class_ids = []
    confidences = []
    boxes = []
    for out in outs:
        for detection in out:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]
            if confidence > 0.5:
                center_x = int(detection[0] * width)
                center_y = int(detection[1] * height)
                w = int(detection[2] * width)
                h = int(detection[3] * height)
                x = center_x - w / 2
                y = center_y - h / 2
                boxes.append([x, y, w, h])
                confidences.append(float(confidence))
                class_ids.append(class_id)

    indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)

    font = cv2.FONT_HERSHEY_PLAIN
    colors = np.random.uniform(0, 255, size=(len(classes), 3))

    for i in range(len(boxes)):
        if i in indexes:
            x, y, w, h = boxes[i]
            label = str(classes[class_ids[i]])
            confidence = confidences[i]
            color = colors[class_ids[i]]
            cv2.rectangle(frame, (int(x), int(y)), (int(x + w), int(y + h)), color, 2)
            text = f"{label}: {confidence:.2f}"
            cv2.putText(frame, text, (int(x), int(y) - 5), font, 1, color, 2)

    resized_frame = cv2.resize(frame, (500, 500))
    cv2.imshow("Video", resized_frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\Skripsi\YOLOv3\Batch256\cobacobatesting256(2).ipynb Cell 2 in <cell line: 16>()
#      <a href='vscode-notebook-cell:/e%3A/Skripsi/YOLOv3/Batch256/cobacobatesting256%282%29.ipynb#W1sZmlsZQ%3D%3D?line=20'>21</a> blob = cv2.dnn.blobFromImage(frame, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
#      <a href='vscode-notebook-cell:/e%3A/Skripsi/YOLOv3/Batch256/cobacobatesting256%282%29.ipynb#W1sZmlsZQ%3D%3D?line=22'>23</a> net.setInput(blob)
# ---> <a href='vscode-notebook-cell:/e%3A/Skripsi/YOLOv3/Batch256/cobacobatesting256%282%29.ipynb#W1sZmlsZQ%3D%3D?line=23'>24</a> outs = net.forward(output_layers)
#      <a href='vscode-notebook-cell:/e%3A/Skripsi/YOLOv3/Batch256/cobacobatesting256%282%29.ipynb#W1sZmlsZQ%3D%3D?line=25'>26</a> class_ids = []
# ...
